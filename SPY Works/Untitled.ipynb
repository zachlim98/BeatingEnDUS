# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import plotly.express as px
from statistics import NormalDist

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
SPY['Adj Close'] = SPY['Adj Close'].pct_change()*100

# %%
SPY.reset_index(inplace=True)
SPY['Date_str'] = SPY["Date"].astype(str)

# %%
SPY
# Out:
#            Date        Open        High         Low       Close  Adj Close  \
# 0    1993-01-29   43.968750   43.968750   43.750000   43.937500        NaN
# 1    1993-02-01   43.968750   44.250000   43.968750   44.250000   0.711220
# 2    1993-02-02   44.218750   44.375000   44.125000   44.343750   0.211834
# 3    1993-02-03   44.406250   44.843750   44.375000   44.812500   1.057093
# 4    1993-02-04   44.968750   45.093750   44.468750   45.000000   0.418423
# ...         ...         ...         ...         ...         ...        ...
# 7119 2021-05-07  419.890015  422.820007  419.160004  422.119995   0.727799
# 7120 2021-05-10  422.500000  422.739990  417.809998  417.940002  -0.990238
# 7121 2021-05-11  413.100006  415.269989  410.059998  414.209991  -0.892475
# 7122 2021-05-12  411.230011  412.589996  404.000000  405.410004  -2.124523
# 7123 2021-05-13  407.070007  412.350006  407.019989  410.279999   1.201252
#
#          Volume    Date_str
# 0       1003200  1993-01-29
# 1        480500  1993-02-01
# 2        201300  1993-02-02
# 3        529400  1993-02-03
# 4        531500  1993-02-04
# ...         ...         ...
# 7119   67680100  2021-05-07
# 7120   81852400  2021-05-10
# 7121  116888000  2021-05-11
# 7122  134811000  2021-05-12
# 7123  106220200  2021-05-13
#
# [7124 rows x 8 columns]

# %%
SPY_violin = px.violin(SPY.reset_index(), x = "Adj Close", orientation="h", 
labels={"variable":" ",
"value":"Percentage Change"},
title="Daily Percentage Change of SPY", hover_data=['Adj Close', 'Date_str'])

SPY_violin.show()

# %%
SPY_hist = px.histogram(SPY.pct_change()*100, x = "Adj Close",
labels={"variable":" ",
"value":"Percentage Change"},
title="Daily Percentage Change of SPY")

SPY_hist.show()

# %%
import numpy as np

print("Mean: " + str(np.mean(perc_change)*100) + "\nStandard Deviation: " + str(np.std(perc_change)*100))
# Out:
# Mean: 0.04585173564133057
# Standard Deviation: 1.1869794451126463

# %%
1 - NormalDist(sigma=np.std(perc_change)*100, mu=np.mean(perc_change)*100).cdf(1.2)
# Out:
# 0.16544057474760354

# %%
import plotly.figure_factory as ff 

x1 = np.random.normal(np.mean(perc_change)*100, np.std(perc_change)*100, 500)
hist_data = [x1]
group_labs = ['Probability']

ff.create_distplot(hist_data, group_labs)
