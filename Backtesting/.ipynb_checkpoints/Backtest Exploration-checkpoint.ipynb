# %%
from datetime import datetime
import backtrader as bt
import backtrader.feeds as btfeeds
import yfinance as yf
import tulipy as ta
import matplotlib.pyplot as plt
import tiingo
import pandas as pd 
import pyfolio as pf
import math

# %matplotlib inline

# %% [markdown]
# # QuantStats

# %%
class TiingoCSVData(btfeeds.GenericCSVData):
    params = (
        ('nullvalue', float('NaN')),
        ('dtformat', '%Y-%m-%d'),
        ('datetime', 0),
        ('open', 9),
        ('high', 7),
        ('low', 8),
        ('close', 6),
        ('volume', 10),
        ('openinterest', -1),
    )

# %%
from tiingo import TiingoClient

client = TiingoClient({'api_key' : '7fb8e25ac6335f846ae82d3f3a28ed535f313592'})

# df = pd.read_csv(R"X:\GitHub\beatingENd\BeatingEnDUS\Own Screener\IBD50.csv")
# datalist = (df['Ticker'].to_list())

datalist = ["XLK", "GE"]

start_date = '2010-02-02'
end_date = '2020-10-10'

for i in range(len(datalist)):
  data = client.get_dataframe(datalist[i],
                                        frequency='daily',
                                        startDate='2020-06-06',
                                        endDate='2020-10-10')
  
  data.tz_convert(None).to_csv("data/ETFs/{}.csv".format(datalist[i]))

# %%
start_date = '2010-02-02'
end_date = '2020-10-10'

index = pd.date_range(start=start_date, end=end_date)
dfdates = pd.DataFrame(index=index)

data = client.get_dataframe("XLC",
                                    frequency='daily',
                                    startDate='2010-02-02',
                                    endDate='2020-10-10')

spy_data = client.get_dataframe("SPY",
                                    frequency='daily',
                                    startDate='2010-02-02',
                                    endDate='2020-10-10')
data = data.tz_convert(None)

dfdates.join(data, how='left').fillna(0).to_csv("data/ETFs/XLC.csv")

# %%
spy_data = client.get_dataframe("SPY",
                                    frequency='daily',
                                    startDate='2010-02-02',
                                    endDate='2020-10-10')

spy_data = spy_data.tz_convert(None)

# %%
dfdates = pd.DataFrame(index=spy_data.index)

data = client.get_dataframe("XLC",
                                    frequency='daily',
                                    startDate='2010-02-02',
                                    endDate='2020-10-10')
data = data.tz_convert(None)

dfdates.join(data, how='left').fillna(0).to_csv("data/ETFs/XLC.csv")

# %%
class RSIt(bt.Strategy):

    params = (('oneplot', True),)

    def __init__(self):
        self.inds = dict()
        for i, d in enumerate(self.datas):
            self.inds[i] = dict()
            self.inds[i]['RSI']= bt.indicators.RelativeStrengthIndex(d)
            self.inds[i]['stoch'] = (bt.indicators.Stochastic(d)).k
            self.inds[i]['ATR']= bt.indicators.AverageTrueRange(d, period=7)
            self.inds[i]['MACD'] = bt.indicators.MACDHisto(d)

            if i > 0:
                if self.p.oneplot == True:
                    d.plotinfo.plotmaster = self.datas[0]

    def next(self):
        for i, d in enumerate(self.datas):
            dt, dn = self.datetime.date(), d._name
            pos = self.getposition(d).size
            cash = self.broker.getcash()
            if not pos:  # no market / no orders
                if (d.close[0] != 0) and (self.inds[i]['RSI'][0] > 50) and (self.inds[i]['stoch'][0] > 50) and (self.inds[i]['MACD'][0] > 0):
                    # self.buy(data=d, size=100)                    
                    price = d.close[0]
                    price_limit = price + (1.5*self.inds[i]['ATR'][0])
                    price_stop = price - (1*self.inds[i]['ATR'][0])
                    qty = round((cash*0.002)/(1*self.inds[i]['ATR'][0]))

                    if qty != 0:    
                        self.buy_bracket(
                            data=d,
                            price=price,
                            size=qty,
                            exectype=bt.Order.Market,
                            stopprice=price_stop,
                            limitprice=price_limit,
                            )
                        print('{} ATR {} is current d'.format(self.inds[i]['ATR'][0], d))

                elif (d.close[0] != 0) and (self.inds[i]['RSI'][0] < 50) and (self.inds[i]['stoch'][0] < 50) and (self.inds[i]['MACD'][0] < 0):
                    # self.sell(data=d, size=100)

                    price = d.close[0]
                    price_limit = price - (1.5*self.inds[i]['ATR'][0])
                    price_stop = price + (1*self.inds[i]['ATR'][0])
                    qty = round((cash*0.002)/(1*self.inds[i]['ATR'][0]))

                    if qty != 0: 
                        self.sell_bracket(
                                data=d,
                                price=price,
                                size=qty,
                                exectype=bt.Order.Market,
                                stopprice=price_stop,
                                limitprice=price_limit,
                            )
            
            elif pos:
                pass
            

    def notify_trade(self, trade):
        dt = self.data.datetime.date()
        if trade.isclosed:
            print('{} {} Closed: PnL Gross {}, Net {}, Cash left {}'.format(
                                                dt,
                                                trade.data._name,
                                                round(trade.pnl,2),
                                                round(trade.pnlcomm,2),
                                                self.broker.getcash()))
            
datalist = ["XLK", "GE"]

# %%
class maCross(bt.Strategy):
    '''
    For an official backtrader blog on this topic please take a look at:

    https://www.backtrader.com/blog/posts/2017-04-09-multi-example/multi-example.html

    oneplot = Force all datas to plot on the same master.
    '''
    params = (
    ('sma1', 40),
    ('sma2', 200),
    ('oneplot', True)
    )

    def __init__(self):
        '''
        Create an dictionary of indicators so that we can dynamically add the
        indicators to the strategy using a loop. This mean the strategy will
        work with any numner of data feeds. 
        '''
        self.inds = dict()
        for i, d in enumerate(self.datas):
            print (i,d)
            self.inds[d] = dict()
            self.inds[d]['sma1'] = bt.indicators.SimpleMovingAverage(
                d.close, period=self.params.sma1)
            self.inds[d]['sma2'] = bt.indicators.SimpleMovingAverage(
                d.close, period=self.params.sma2)
            self.inds[d]['cross'] = bt.indicators.CrossOver(self.inds[d]['sma1'],self.inds[d]['sma2'])
            self.inds[d]['ATR'] = bt.indicators.AverageTrueRange(d, period=7)

            if i > 0: #Check we are not on the first loop of data feed:
                if self.p.oneplot == True:
                    d.plotinfo.plotmaster = self.datas[0]

    def next(self):
        for i, d in enumerate(self.datas):
            dt, dn = self.datetime.date(), d._name
            pos = self.getposition(d).size
            if not pos:  # no market / no orders
                if self.inds[d]['cross'][0] == 1:
                    self.buy(data=d, size=1000)
                elif self.inds[d]['cross'][0] == -1:
                    self.sell(data=d, size=1000)
            else:
                if self.inds[d]['cross'][0] == 1:
                    self.close(data=d)
                    self.buy(data=d, size=1000)
                elif self.inds[d]['cross'][0] == -1:
                    self.close(data=d)
                    self.sell(data=d, size=1000)

    def notify_trade(self, trade):
        dt = self.data.datetime.date()
        if trade.isclosed:
            print('{} {} Closed: PnL Gross {}, Net {}'.format(
                                                dt,
                                                trade.data._name,
                                                round(trade.pnl,2),
                                                round(trade.pnlcomm,2)))

# %%
if __name__ == '__main__':
    cerebro = bt.Cerebro()
    cerebro.addstrategy(RSIt, oneplot=False)
    cerebro.broker.setcash(100000.0)
    cerebro.addanalyzer(bt.analyzers.PyFolio) #add analyzer

    #Loop through the list adding to cerebro.
    for i in range(len(datalist)):
        data = TiingoCSVData(dataname="data/ETFs/{}.csv".format(datalist[i]))
        cerebro.adddata(data, name=datalist[i])

    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
    strats = cerebro.run(runonce=False)
    firstStrat = strats[0]
    print('Ending Portfolio Value: %.2f' % cerebro.broker.getvalue())

    cerebro.plot()
# Out:
# Starting Portfolio Value: 100000.00
# 2.163901732426387 ATR <__main__.TiingoCSVData object at 0x2A808208> is current d
# 2020-07-30 GE Closed: PnL Gross 287.17, Net 287.17, Cash left 89905.2724304154
# 2020-07-31 XLK Closed: PnL Gross 412.95, Net 412.95, Cash left 104749.73773096937
# 2.260233392386734 ATR <__main__.TiingoCSVData object at 0x2A808208> is current d
# 2020-08-05 XLK Closed: PnL Gross 176.11, Net 176.11, Cash left 104925.84547544052
# 1.9900706239199266 ATR <__main__.TiingoCSVData object at 0x2A808208> is current d
# 2020-08-10 GE Closed: PnL Gross -186.24, Net -186.24, Cash left 88770.27124480902
# 2020-08-11 XLK Closed: PnL Gross -199.53, Net -199.53, Cash left 100490.45904050443
# 2.1490392704140877 ATR <__main__.TiingoCSVData object at 0x2A808208> is current d
# 2020-08-13 XLK Closed: PnL Gross 218.6, Net 218.6, Cash left 100709.05865832182
# 2.118030444757288 ATR <__main__.TiingoCSVData object at 0x2A808208> is current d
# ...

# %%
pyfoliozer = firstStrat.analyzers.getbyname('pyfolio')
returns, positions, transactions, gross_lev = pyfoliozer.get_pf_items()

# %%
import quantstats as qs

returns_qs = returns.tz_convert(None)
transactions_qs = transactions.tz_convert(None)
positions_qs = positions.tz_convert(None)

# %%
qs.reports.full(returns_qs,"SPY")
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               2010-02-02  2010-02-02
# End Period                 2020-10-09  2020-10-09
# Risk-Free Rate             0.0%        0.0%
# Time in Market             94.0%       100.0%
#
# Cumulative Return          -69.13%     294.02%
# CAGR%                      -10.41%     13.69%
# Sharpe                     -0.47       0.83
# Sortino                    -0.68       1.15
# Max Drawdown               -74.84%     -33.72%
# Longest DD Days            3819        277
# Volatility (ann.)          19.55%      17.29%
# R^2                        0.05        0.05
# Calmar                     -0.14       0.41
# Skew                       1.63        -0.62
# Kurtosis                   63.54       13.69
#
# Expected Daily %           -0.04%      0.05%
# Expected Monthly %         -0.91%      1.07%
# Expected Yearly %          -10.13%     13.28%
# ...

# %%
transactions.to_csv("ttub.csv")

# %%
pf.create_full_tear_sheet(returns=returns,transactions=transactions)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-06-08</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-10-09</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>4</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
# ...

# %%
import backtrader as bt
from datetime import datetime


class maCross(bt.Strategy):
    '''
    For an official backtrader blog on this topic please take a look at:

    https://www.backtrader.com/blog/posts/2017-04-09-multi-example/multi-example.html

    oneplot = Force all datas to plot on the same master.
    '''
    params = (
    ('sma1', 40),
    ('sma2', 200),
    ('oneplot', True)
    )

    def __init__(self):
        '''
        Create an dictionary of indicators so that we can dynamically add the
        indicators to the strategy using a loop. This mean the strategy will
        work with any numner of data feeds. 
        '''
        self.inds = dict()
        for i, d in enumerate(self.datas):
            self.inds[d] = dict()
            self.inds[d]['sma1'] = bt.indicators.SimpleMovingAverage(
                d.close, period=self.params.sma1)
            self.inds[d]['sma2'] = bt.indicators.SimpleMovingAverage(
                d.close, period=self.params.sma2)
            self.inds[d]['cross'] = bt.indicators.CrossOver(self.inds[d]['sma1'],self.inds[d]['sma2'])
            self.inds[d]['ATR'] = bt.talib.ATR(high=d.high, low=d.low, close=d.close, timeperiod=7)

            if i > 0: #Check we are not on the first loop of data feed:
                if self.p.oneplot == True:
                    d.plotinfo.plotmaster = self.datas[0]

    def next(self):
        for i, d in enumerate(self.datas):
            dt, dn = self.datetime.date(), d._name
            pos = self.getposition(d).size
            if not pos:  # no market / no orders
                if self.inds[d]['cross'][0] == 1:
                    self.buy(data=d, size=1000)
                elif self.inds[d]['cross'][0] == -1:
                    self.sell(data=d, size=1000)
            else:
                if self.inds[d]['cross'][0] == 1:
                    self.close(data=d)
                    self.buy(data=d, size=1000)
                elif self.inds[d]['cross'][0] == -1:
                    self.close(data=d)
                    self.sell(data=d, size=1000)

    def notify_trade(self, trade):
        dt = self.data.datetime.date()
        if trade.isclosed:
            print('{} {} Closed: PnL Gross {}, Net {}'.format(
                                                dt,
                                                trade.data._name,
                                                round(trade.pnl,2),
                                                round(trade.pnlcomm,2)))


class OandaCSVData(bt.feeds.GenericCSVData):
    params = (
        ('nullvalue', float('NaN')),
        ('dtformat', '%Y-%m-%dT%H:%M:%S.%fZ'),
        ('datetime', 6),
        ('time', -1),
        ('open', 5),
        ('high', 3),
        ('low', 4),
        ('close', 1),
        ('volume', 7),
        ('openinterest', -1),
    )


#Variable for our starting cash
startcash = 10000

#Create an instance of cerebro
cerebro = bt.Cerebro()

#Add our strategy
cerebro.addstrategy(maCross, oneplot=False)

#create our data list
datalist = [
    ('data/CAD_CHF-2005-2017-D1.csv', 'CADCHF'), #[0] = Data file, [1] = Data name
    ('data/EUR_USD-2005-2017-D1.csv', 'EURUSD'),
]

#Loop through the list adding to cerebro.
for i in range(len(datalist)):
    data = OandaCSVData(dataname=datalist[i][0])
    cerebro.adddata(data, name=datalist[i][1])


# Set our desired cash start
cerebro.broker.setcash(startcash)

# Run over everything
cerebro.run()

#Get final portfolio Value
portvalue = cerebro.broker.getvalue()
pnl = portvalue - startcash

#Print out the final result
print('Final Portfolio Value: ${}'.format(portvalue))
print('P/L: ${}'.format(pnl))

#Finally plot the end results
cerebro.plot(style='candlestick')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-8e3039562278> in <module>
#     104
#     105 # Run over everything
# --> 106 cerebro.run()
#     107
#     108 #Get final portfolio Value
#
# X:\Environments\Backtesting\lib\site-packages\backtrader\cerebro.py in run(self, **kwargs)
#    1125             # let's skip process "spawning"
#    1126             for iterstrat in iterstrats:
# -> 1127                 runstrat = self.runstrategies(iterstrat)
#    1128                 self.runstrats.append(runstrat)
#    1129                 if self._dooptimize:
#
# X:\Environments\Backtesting\lib\site-packages\backtrader\cerebro.py in runstrategies(self, iterstrat, predata)
#    1215             sargs = self.datas + list(sargs)
#    1216             try:
# -> 1217                 strat = stratcls(*sargs, **skwargs)
# ...
